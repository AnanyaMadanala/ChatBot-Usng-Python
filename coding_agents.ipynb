# %% [markdown]
# <a href="https://colab.research.google.com/github/AnanyaMadanala/ChatBot-Usng-Python/blob/main/coding_agents.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# AGENT 1 - content generator agent

# %%
# !pip install -q google-generativeai

# %%
import google.generativeai as genai

genai.configure(api_key="place your own API key")

model = genai.GenerativeModel("gemini-2.5-flash")
# Out:
# /usr/local/lib/python3.12/dist-packages/google/colab/_import_hooks/_hook_injector.py:55: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   loader.exec_module(module)

# %%
def content_generator_agent(topic, content_type, tone, length):
    prompt = f"""
    You are a professional content writer.

    Generate a {content_type} on the topic: "{topic}"

    Tone: {tone}
    Length: {length}

    Guidelines:
    - Be clear and engaging
    - Use simple language
    - Avoid emojis
    """

    response = model.generate_content(prompt)
    return response.text.replace("*", "")

# %%
topic = "Benefits of Artificial Intelligence"
content_type = "LinkedIn post"
tone = "professional but friendly"
length = "150 words"

output = content_generator_agent(topic, content_type, tone, length)
print(output)
# Out:
# Here's a LinkedIn post on the benefits of Artificial Intelligence:
#
# Artificial intelligence (AI) is rapidly transforming our world, offering more than just technological advancements – it delivers real, measurable benefits across countless sectors.
#
# At its core, AI is a powerful enabler. It significantly boosts efficiency by automating repetitive and time-consuming tasks, allowing human teams to dedicate their expertise to strategic thinking and creativity. This doesn't just save time; it elevates the quality of work and accelerates progress.
#
# Furthermore, AI's ability to process and analyze massive datasets unlocks unprecedented insights. Businesses can make smarter, data-driven decisions, identify trends, and predict outcomes with greater accuracy. This predictive power fuels innovation, pushing the boundaries of what's possible in fields from healthcare to customer service, where personalized experiences are becoming the norm.
#
# Ultimately, AI empowers us to work smarter, innovate faster, and create more value.
#
# What benefits of AI are you most excited about, or already seeing in your industry? Share your perspective!
#
# #ArtificialIntelligence #AI #Innovation #DigitalTransformation #BusinessGrowth

# %% [markdown]
# AGENT 2 - interview question generator agent

# %%
# !pip install -q google-generativeai

# %%
import google.generativeai as genai

genai.configure(api_key="AIzaSyA7RY7YHTX8TXYsU1GJe_RoGV99lV5flo8")

model = genai.GenerativeModel("gemini-2.5-flash")

# %%
def interview_question_agent(role, experience, skills=None, include_answers=False):
    skills_text = ", ".join(skills) if skills else "general relevant skills"

    answer_instruction = ""
    if include_answers:
        answer_instruction = "Also provide a short sample answer for each question."

    prompt = f"""
    You are a senior technical interviewer.

    Generate interview questions for the following:
    Role: {role}
    Experience Level: {experience}
    Skills: {skills_text}

    Requirements:
    - 5 interview questions
    - Questions should match the experience level
    - Be clear and professional
    {answer_instruction}
    """

    response = model.generate_content(prompt)
    return response.text.replace("*", "")

# %%
output = interview_question_agent(
    role="Python Developer",
    experience="Fresher",
    skills=["Python", "OOP", "Basic SQL"]
)

print(output)
# Out:
# Here are 5 interview questions for a Python Developer (Fresher) role, covering Python, OOP, and Basic SQL:
#
# ---
#
# Interview Questions: Python Developer (Fresher)
#
# 1.  Python Fundamentals:
#     Can you explain the difference between a `list` and a `tuple` in Python? When would you choose to use one over the other in your code?
#
# 2.  Python Coding Challenge:
#     Write a simple Python function called `find_max_value` that takes a list of integers as input and returns the largest number in that list. If the list is empty, it should return `None`.
#
# 3.  Object-Oriented Programming (OOP) Concepts:
#     What are the four fundamental principles (or pillars) of Object-Oriented Programming? Briefly describe each principle.
#
# 4.  OOP Application:
#     Imagine you are building a very basic application to manage different types of vehicles. How would you design a Python class named `Vehicle`? What are some common attributes (like `make`, `model`, `year`) and a couple of simple methods (like `start_engine`, `display_info`) this class might have?
#
# 5.  Basic SQL Queries:
#     You are given a database table named `Products` with the following columns: `product_id` (integer), `product_name` (string), `category` (string), `price` (decimal), and `stock_quantity` (integer).
#        a) Write a SQL query to retrieve the `product_name` and `price` of all products that belong to the 'Electronics' category.
#        b) Write a SQL query to insert a new product with `product_name` 'Wireless Mouse', `category` 'Accessories', `price` 25.00, and `stock_quantity` 150 into the `Products` table.

# %%
output = interview_question_agent(
    role="Machine Learning Engineer",
    experience="2-3 years",
    skills=["Python", "Scikit-learn", "Model evaluation"],
    include_answers=True
)

print(output)
# Out:
# Here are 5 interview questions for a Machine Learning Engineer with 2-3 years of experience, focusing on Python, Scikit-learn, and Model Evaluation, along with sample answers.
#
# ---
#
# ### Machine Learning Engineer Interview Questions (2-3 Years Experience)
#
# 1. Question: Walk us through your process of building a predictive model using Scikit-learn, starting from raw data to a trained model. Highlight any best practices you follow to ensure robust model development and avoid common issues like data leakage.
#
# Sample Answer:
# "My typical process starts with Exploratory Data Analysis (EDA) to understand the data's structure, identify missing values, outliers, and distributions. Before any preprocessing, I perform a strict train-test split (or train-validation-test split) to simulate unseen data and prevent data leakage.
# Next, I handle data preprocessing:
#    Imputation for missing values (e.g., `SimpleImputer`).
#    Feature scaling for numerical features (e.g., `StandardScaler`, `MinMaxScaler`).
#    Encoding for categorical features (e.g., `OneHotEncoder`, `OrdinalEncoder`).
# I often use Scikit-learn's `Pipeline` and `ColumnTransformer` to encapsulate these steps, ensuring consistent transformations and preventing data leakage across folds during cross-validation.
# For model selection, I start with simpler models (e.g., `LogisticRegression`, `RandomForestClassifier`) and then explore more complex ones if needed. Hyperparameter tuning is crucial; I use `GridSearchCV` or `RandomizedSearchCV` with `cross_val_score` or `StratifiedKFold` to find optimal parameters while maintaining generalization.
# Finally, I evaluate the best model on the held-out test set using appropriate metrics. Throughout the process, I focus on code modularity, reproducibility, and version control."
#
# ---
#
# 2. Question: You've built a classification model that predicts a rare disease. Your model achieves 98% accuracy on the test set. Would you deploy this model immediately? Explain what other metrics and considerations you would evaluate and why, especially in the context of imbalanced datasets.
#
# Sample Answer:
# "No, I would definitely not deploy it immediately. While 98% accuracy sounds impressive, for a rare disease, this could be misleading due to an imbalanced dataset. If only 1% of the population has the disease, a model that simply predicts 'no disease' for everyone would achieve 99% accuracy, which is useless.
# In this context, I would prioritize:
#    Recall (Sensitivity): To minimize false negatives (missing actual disease cases). This is often critical for rare disease detection.
#    Precision: To minimize false positives (incorrectly diagnosing someone with the disease), which can lead to unnecessary stress and follow-up tests.
#    F1-Score: The harmonic mean of precision and recall, providing a balanced measure.
#    ROC AUC: To assess the model's ability to discriminate between positive and negative classes across various thresholds.
#    Confusion Matrix: To get a detailed breakdown of true positives, true negatives, false positives, and false negatives.
# I would also consider the business or medical impact of false positives versus false negatives. Sometimes, a higher recall is preferred even at the cost of lower precision, depending on the severity of the disease and consequences of misdiagnosis."
#
# ---
#
# 3. Question: Imagine you've trained a classification model using Scikit-learn, and after initial evaluation, you find it's performing very well on your training data but poorly on unseen test data. What could be the potential reasons for this discrepancy, and what practical steps would you take, using Scikit-learn tools or general ML techniques, to diagnose and mitigate this overfitting?
#
# Sample Answer:
# "This scenario strongly suggests overfitting, where the model has learned the training data too well, including its noise and specific patterns, losing its ability to generalize to new, unseen data.
#
# Potential Reasons:
#    Model Complexity: The model might be too complex for the given data (e.g., a deep decision tree, high-degree polynomial regression).
#    Insufficient Data: Not enough training data relative to the model's complexity or the number of features.
#    Too Many Features: Irrelevant or noisy features can cause the model to overfit.
#    Data Leakage: Unintentional leakage of information from the test set into the training process.
#
# Diagnosis and Mitigation Steps:
# 1.  Learning Curves: Plot training and cross-validation scores against the number of training samples. A large gap between high training score and low cross-validation score indicates overfitting.
# 2.  Regularization: Implement regularization techniques. For linear models, `LogisticRegression` and `SGDClassifier` in Scikit-learn have L1/L2 penalties (`penalty='l1'`, `penalty='l2'`). For tree-based models like `RandomForestClassifier` or `GradientBoostingClassifier`, I'd tune hyperparameters like `max_depth`, `min_samples_leaf`, `min_samples_split`, or `n_estimators`.
# 3.  Feature Engineering/Selection:
#        Dimensionality Reduction: Use techniques like PCA (`decomposition.PCA`) if features are highly correlated.
#        Feature Selection: Use `SelectKBest`, `RFE (Recursive Feature Elimination)`, or L1 regularization (which can drive some coefficients to zero) to reduce the number of features.
#        Domain Knowledge: Remove or combine features based on domain expertise.
# 4.  Increase Training Data: If feasible, collecting more diverse training data is often the most effective solution.
# 5.  Simplify the Model: Try a simpler model with fewer parameters or less capacity.
# 6.  Cross-validation: Ensure robust evaluation using k-fold cross-validation to get a more reliable estimate of generalization error."
#
# ---
#
# 4. Question: Scikit-learn offers powerful tools like `Pipeline` and `ColumnTransformer`. Describe their primary benefits in an ML workflow. Can you provide a practical example of how you might combine them to preprocess a dataset with mixed data types before training a model?
#
# Sample Answer:
# "Both `Pipeline` and `ColumnTransformer` are crucial for creating robust, maintainable, and production-ready ML workflows.
#
# Benefits:
#    Workflow Streamlining: They chain multiple preprocessing steps and a final estimator into a single Scikit-learn object, making the entire process cleaner and more efficient.
#    Data Leakage Prevention: By applying transformations consistently within cross-validation folds (e.g., fitting scalers only on the training data for each fold), they effectively prevent data leakage.
#    Code Readability and Maintainability: They consolidate complex preprocessing logic, making the code easier to read, understand, and modify.
#    Reproducibility: A single `Pipeline` object can be saved and reloaded to apply the exact same transformations and model to new data.
#
# Practical Example (Combined Use):
# Let's say we have a dataset with numerical features that need scaling and categorical features that need one-hot encoding, and we want to train a `LogisticRegression` model.
#
# ```python
# from sklearn.pipeline import Pipeline
# from sklearn.compose import ColumnTransformer
# from sklearn.preprocessing import StandardScaler, OneHotEncoder
# from sklearn.linear_model import LogisticRegression
# import pandas as pd
# import numpy as np
#
# # Sample Data
# data = pd.DataFrame({
#     'age': [25, 30, 35, 40, 45, 20],
#     'salary': [50000, 60000, 75000, 90000, 100000, 40000],
#     'city': ['NY', 'SF', 'NY', 'LA', 'SF', 'LA'],
#     'gender': ['M', 'F', 'M', 'F', 'M', 'F'],
#     'target': [0, 1, 0, 1, 0, 1]
# })
#
# numerical_features = ['age', 'salary']
# categorical_features = ['city', 'gender']
#
# # Create preprocessing steps for different column types
# numerical_transformer = StandardScaler()
# categorical_transformer = OneHotEncoder(handle_unknown='ignore') # Ignore new categories in test set
#
# # Combine transformers using ColumnTransformer
# preprocessor = ColumnTransformer(
#     transformers=[
#         ('num', numerical_transformer, numerical_features),
#         ('cat', categorical_transformer, categorical_features)
#     ])
#
# # Create the full pipeline
# model_pipeline = Pipeline(steps=[
#     ('preprocessor', preprocessor),
#     ('classifier', LogisticRegression(solver='liblinear'))
# ])
#
# # Now, model_pipeline can be trained directly on the raw X, y data
# X = data.drop('target', axis=1)
# y = data['target']
#
# # From here, you would typically split X, y into train/test and then:
# # model_pipeline.fit(X_train, y_train)
# # predictions = model_pipeline.predict(X_test)
# ```
# In this example, `ColumnTransformer` handles the specific transformations per column type, and this entire `preprocessor` then becomes the first step in the `Pipeline`, ensuring that data flows seamlessly from raw format to a model-ready state, without manual intermediate steps."
#
# ---
#
# 5. Question: When evaluating a regression model using Scikit-learn, what are the primary metrics you would typically use, and under what circumstances might you prefer one over another (e.g., MAE vs. RMSE)?
#
# Sample Answer:
# "For evaluating regression models in Scikit-learn, the primary metrics I typically use are:
#
# 1.  Mean Absolute Error (MAE): This is the average of the absolute differences between predictions and actual values.
#        Formula: `sum(|y_true - y_pred|) / n`
#        Preference: I prefer MAE when I want a metric that is robust to outliers. Since it takes the absolute difference, large errors don't disproportionately inflate the metric. It's also more interpretable in the original units of the target variable.
#
# 2.  Mean Squared Error (MSE): This is the average of the squared differences between predictions and actual values.
#        Formula: `sum((y_true - y_pred)^2) / n`
#        Preference: MSE heavily penalizes large errors due to the squaring. It's often used when large errors are particularly undesirable or costly. It's also differentiable, which makes it useful in many optimization algorithms. However, its value is not in the same unit as the target variable, making direct interpretation harder.
#
# 3.  Root Mean Squared Error (RMSE): This is simply the square root of the MSE.
#        Formula: `sqrt(sum((y_true - y_pred)^2) / n)`
#        Preference: RMSE is very commonly used as it brings the error back into the same units as the target variable, making it more interpretable than MSE while still penalizing larger errors more than MAE. It's a good general-purpose metric when you want to emphasize the impact of larger errors without going as extreme as squaring them directly.
#
# 4.  R-squared (Coefficient of Determination): This metric represents the proportion of the variance in the dependent variable that is predictable from the independent variables.
#        Formula: `1 - (SS_res / SS_tot)` where SS_res is the sum of squared residuals and SS_tot is the total sum of squares.
#        Preference: R-squared provides an intuitive measure of how well the model explains the variability of the target variable. A value closer to 1 indicates a better fit. It's good for understanding the overall explanatory power, but it doesn't tell you the magnitude of the errors directly like MAE or RMSE. It can be misleading if the model is overfit or if new features are added without true predictive power, as it generally increases with more predictors. For that, Adjusted R-squared (though not directly available in Scikit-learn for basic regression) is often preferred in statistical modeling.
#
# In summary, if I need a robust and directly interpretable error, I lean towards MAE. If I want to heavily penalize large errors and my model's optimization relies on squared errors, RMSE is a strong choice. R-squared gives a good sense of the model's overall explanatory power."

# %% [markdown]
# AGENT 3 - code review agent

# %%
def code_review_agent(code, language="Python"):
    prompt = f"""
    You are a senior {language} software engineer.

    Review the following code and provide:
    1. Bugs or logical issues (if any)
    2. Code quality and readability feedback
    3. Performance or optimization suggestions
    4. Best practices recommendations

    Code:
    ```{language.lower()}
    {code}
    ```
    """

    response = model.generate_content(prompt)
    return response.text.replace("*", "")

# %%
python_code = """
def factorial(n):
    fact = 1
    for i in range(1, n+1):
        fact = fact * i
    return fact
"""

review = code_review_agent(python_code, language="Python")
print(review)
# Out:
# As a senior Python software engineer, I've reviewed your `factorial` function. Here's my feedback:
#
# ---
#
# ### 1. Bugs or Logical Issues
#
# *   **Negative Input (`n < 0`):** The most significant logical issue is how the function handles negative integers.
#     *   The factorial function is typically defined only for non-negative integers (0, 1, 2, ...).
#     *   For `n = 0`, `range(1, 1)` is empty, `fact` remains `1`, which is correct (0! = 1).
#     *   For `n < 0` (e.g., `n = -5`), `range(1, -4)` is also an empty range. The function will return `1`, which is mathematically incorrect for negative factorials. Standard practice would be to raise an error for invalid input.
#
# *   **Non-Integer Input:** The function assumes `n` is an integer. If `n` is a float (e.g., `3.5`), a `TypeError` will be raised by `range()`. While this implicitly handles non-integer types, explicit validation and a more specific error message would be better.
#
# ---
#
# ### 2. Code Quality and Readability Feedback
#
# *   **Clarity:** The code is very clear, concise, and easy to understand. The iterative approach is straightforward.
# *   **Variable Names:** `n`, `fact`, and `i` are standard and perfectly appropriate for this context.
# *   **PEP 8 Compliance:** The code generally adheres to PEP 8 guidelines regarding spacing and naming.
# *   **Docstrings:** The function is missing a docstring. A docstring is crucial for explaining what the function does, its parameters, what it returns, and any specific behaviors (like how it handles edge cases or invalid input).
#
# ---
#
# ### 3. Performance or Optimization Suggestions
#
# *   **Current Algorithm:** The iterative approach using a `for` loop is very efficient for calculating factorials in Python for reasonably sized `n`. Python's integers automatically handle arbitrary precision, so you don't need to worry about overflow for large results, though calculation time will increase.
# *   **Recursion vs. Iteration:** While factorial can be implemented recursively, the iterative version typically performs better in Python due to lower function call overhead and avoidance of recursion depth limits for very large `n`. So, your choice of iteration is good for performance.
# *   **Memoization/Caching (for repeated calls):** If this function were to be called many times with the *same* input values for `n` within the lifetime of an application, you could significantly optimize repeated computations using caching (memoization).
#     *   You could use `functools.lru_cache` from the standard library.
#
#     ```python
#     import functools
#
#     @functools.lru_cache(maxsize=None) # maxsize=None means cache all results
#     def factorial_cached(n):
#         # ... your existing logic ...
#         if not isinstance(n, int):
#             raise TypeError("n must be an integer")
#         if n < 0:
#             raise ValueError("n must be a non-negative integer")
#
#         fact = 1
#         for i in range(1, n + 1):
#             fact = fact * i
#         return fact
#     ```
#     *   **Caveat:** For a function that's called infrequently or always with different `n`, the overhead of caching might negate any benefits. For *this specific* simple function, caching is generally not needed unless there's a clear use case for repeated computations.
#
# ---
#
# ### 4. Best Practices Recommendations
#
# 1.  **Add a Docstring:** Always include a docstring for your functions. It describes the purpose, arguments, and return value.
#
#     ```python
#     def factorial(n):
#         """
#         Calculates the factorial of a non-negative integer.
#
#         The factorial of a non-negative integer n, denoted by n!, is the
#         product of all positive integers less than or equal to n.
#         The factorial of 0 is 1.
#
#         Args:
#             n (int): A non-negative integer.
#
#         Returns:
#             int: The factorial of n.
#
#         Raises:
#             TypeError: If n is not an integer.
#             ValueError: If n is a negative integer.
#         """
#         # ... rest of your code ...
#     ```
#
# 2.  **Input Validation and Error Handling:** Explicitly validate `n` to ensure it's a non-negative integer. This makes your function more robust and predictable.
#
#     ```python
#     def factorial(n):
#         if not isinstance(n, int):
#             raise TypeError("n must be an integer")
#         if n < 0:
#             raise ValueError("n must be a non-negative integer")
#
#         fact = 1
#         for i in range(1, n + 1):
#             fact = fact * i
#         return fact
#     ```
#
# 3.  **Type Hinting:** Add type hints to improve code readability, allow static analysis tools (like MyPy) to catch potential type-related errors early, and make the function's signature clearer.
#
#     ```python
#     def factorial(n: int) -> int:
#         # ...
#     ```
#     Combining with the above:
#     ```python
#     def factorial(n: int) -> int:
#         """
#         Calculates the factorial of a non-negative integer.
#         ... (docstring content) ...
#         """
#         if not isinstance(n, int):
#             # This check is technically redundant if type checkers are used and enforced,
#             # but can be useful for runtime safety for users not using type checkers.
#             # Depending on project policy, you might omit it if you strictly enforce types.
#             raise TypeError("n must be an integer")
#         if n < 0:
#             raise ValueError("n must be a non-negative integer")
#
#         fact = 1
#         for i in range(1, n + 1):
#             fact = fact * i
#         return fact
#     ```
#
# 4.  **Use `math.factorial` for Production Code:** For real-world applications where you need to calculate factorials, it's almost always best to use the built-in `math.factorial` function. It's implemented in C, highly optimized, and handles error conditions correctly. Re-implementing fundamental mathematical functions like this is generally discouraged unless you have a very specific pedagogical or research reason.
#
#     ```python
#     import math
#
#     # In most cases, you would simply use:
#     result = math.factorial(5)
#     print(result) # Output: 120
#     ```
#
# ---
#
# ### Summary
#
# Your current code is a perfectly functional and readable implementation of factorial for non-negative integers. The primary areas for improvement are robustness through input validation and error handling, and adhering to Pythonic best practices like docstrings and type hints. For production-grade code, leveraging `math.factorial` is the recommended approach.

# %% [markdown]
# agent 4 - college query agent

# %%
import requests
from bs4 import BeautifulSoup

def fetch_website_text(url, max_chars=6000):
    response = requests.get(url, timeout=10)
    soup = BeautifulSoup(response.text, "html.parser")

    # Remove scripts and styles
    for tag in soup(["script", "style", "noscript"]):
        tag.decompose()

    text = " ".join(soup.stripped_strings)

    # Limit size to avoid context overflow
    return text[:max_chars]

# %%
def college_query_agent_website(url, user_question):
    website_text = fetch_website_text(url)

    prompt = f"""
    You are a college helpdesk chatbot.

    Answer the user's question using ONLY the information
    from the college website content below.

    If the answer is not found, say:
    "I'm sorry, this information is not available on the website."

    College Website Content:
    {website_text}

    User Question:
    {user_question}
    """

    response = model.generate_content(prompt)
    return response.text.replace("*", "")

# %%
college_website = "https://www.medicaps.ac.in/"

question = "what is the name of the college?"
answer = college_query_agent_website(college_website, question)

print(answer)
# Out:
# The name of the college is Medicaps University.

# %% [markdown]
# agent 5 - code with knowledge base

# %%
college_data = {
    "name": "ABC Institute of Technology",
    "location": "Mangalore",
    "courses": [
        "Computer Science Engineering",
        "Artificial Intelligence & Machine Learning",
        "Information Science",
        "Electronics and Communication"
    ],
    "fees": {
        "CSE": "₹1,50,000 per year",
        "AIML": "₹1,75,000 per year"
    },
    "college_timings": "9:00 AM to 4:30 PM",
    "placements": {
        "highest_package": "₹12 LPA",
        "average_package": "₹4.5 LPA",
        "top_companies": ["TCS", "Infosys", "Accenture", "Wipro"]
    },
    "contact": {
        "email": "info@abcit.edu",
        "phone": "+91-9876543210"
    }
}

# %%
def college_query_agent(user_question):
    prompt = f"""
    You are a college helpdesk chatbot.

    Answer the user's question using ONLY the information provided below.
    If the answer is not available, politely say:
    "I'm sorry, I don't have that information."

    College Information:
    {college_data}

    User Question:
    {user_question}
    """

    response = model.generate_content(prompt)
    return response.text.replace("*", "")

# %%
question = "What is the fee for AI and ML course?"
answer = college_query_agent(question)
print(answer)
# Out:
# The fee for the Artificial Intelligence & Machine Learning (AIML) course is ₹1,75,000 per year.

# %% [markdown]
# agent 6

# %%
# !pip install -q google-generativeai pdfplumber
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 1.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 54.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 76.0 MB/s eta 0:00:00

# %%
from google.colab import files

uploaded = files.upload()
resume_path = list(uploaded.keys())[0]

# %%
import pdfplumber

def extract_resume_text(pdf_path):
    text = ""
    with pdfplumber.open(pdf_path) as pdf:
        for page in pdf.pages:
            text += page.extract_text() + "\n"
    return text

# %%
resume_text = extract_resume_text(resume_path)
print(resume_text[:1000])  # preview

# %%
job_description = """
We are looking for a Python Developer with knowledge of:
- Python
- OOP concepts
- SQL
- Basic Machine Learning
- REST APIs

Experience: 0–2 years
"""

# %%
def resume_screener_agent(resume_text, job_description):
    prompt = f"""
    You are an AI HR assistant.

    Analyze the resume and compare it with the job description.

    Resume:
    {resume_text}

    Job Description:
    {job_description}

    Provide the output in the following format:

    1. Key Skills Found
    2. Relevant Experience Summary
    3. Skill Match Percentage (0–100)
    4. Strengths
    5. Weaknesses / Missing Skills
    6. Final Recommendation (Hire / Consider / Reject)
    """

    response = model.generate_content(prompt)
    return response.text.replace("*", "")

# %%
result = resume_screener_agent(resume_text, job_description)
print(result)

# %% [markdown]
# langraph and langchain

# %%
# !pip install -q langchain langgraph langchain-google-genai google-generativeai speechrecognition gtts pydub

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    google_api_key="place your own API key",
    temperature=0.3
)

# %%
from IPython.display import Javascript, display
from base64 import b64decode
from google.colab import output

def record_audio(seconds=5):
    display(Javascript(f"""
    async function recordAudio() {{
        const stream = await navigator.mediaDevices.getUserMedia({{ audio: true }});
        const recorder = new MediaRecorder(stream);
        const chunks = [];

        recorder.ondataavailable = e => chunks.push(e.data);
        recorder.start();

        await new Promise(r => setTimeout(r, {seconds} * 1000));
        recorder.stop();

        await new Promise(r => recorder.onstop = r);

        const blob = new Blob(chunks);
        const buffer = await blob.arrayBuffer();
        const base64 = btoa(
            new Uint8Array(buffer).reduce((d, b) => d + String.fromCharCode(b), '')
        );
        google.colab.kernel.invokeFunction(
            'notebook.save_audio', [base64], {{}}
        );
    }}
    recordAudio();
    """))

def save_audio(base64_audio):
    audio_bytes = b64decode(base64_audio)
    with open("input.wav", "wb") as f:
        f.write(audio_bytes)

output.register_callback("notebook.save_audio", save_audio)

# %%
import speech_recognition as sr
from pydub import AudioSegment
import os

def speech_to_text_node(state):
    recognizer = sr.Recognizer()

    input_file = "input.wav"
    temp_wav_file = "temp_input.wav"

    try:
        # Load the input audio file (which might be webm or another format)
        audio = AudioSegment.from_file(input_file)
        # Export as a standard 16-bit PCM, single-channel WAV file
        audio.export(temp_wav_file, format="wav", codec="pcm_s16le", parameters=["-ac", "1"])
    except Exception as e:
        return {"text": f"Error during audio conversion with pydub: {e}"}

    # Check if the temporary WAV file was actually created and has content
    if not os.path.exists(temp_wav_file) or os.path.getsize(temp_wav_file) == 0:
        return {"text": "Error: Temporary WAV file was not created or is empty."}

    try:
        with sr.AudioFile(temp_wav_file) as source:
            audio_data = recognizer.record(source)
        text = recognizer.recognize_google(audio_data)
    except sr.UnknownValueError:
        text = "Speech Recognition could not understand audio."
    except sr.RequestError as e:
        text = f"Could not request results from Google Speech Recognition service; {e}"
    except Exception as e:
        text = f"An unexpected error occurred during speech recognition: {e}"
    finally:
        # Clean up the temporary file
        if os.path.exists(temp_wav_file):
            os.remove(temp_wav_file)

    return {"text": text}

# %%
def llm_node(state):
    user_text = state["text"]
    response = llm.invoke(user_text)
    # Remove asterisks from the response
    cleaned_response = response.content.replace("*", "")
    return {"response": cleaned_response}

# %%
from gtts import gTTS
from IPython.display import Audio

def tts_node(state):
    tts = gTTS(state["response"])
    tts.save("response.mp3")
    return {"audio": Audio("response.mp3", autoplay=True)}

# %%
from typing import TypedDict

class VoiceAgentState(TypedDict):
    text: str
    response: str
    audio: object

# %%
from langgraph.graph import StateGraph, END

graph = StateGraph(VoiceAgentState)

graph.add_node("stt", speech_to_text_node)
graph.add_node("llm", llm_node)
graph.add_node("tts", tts_node)

graph.set_entry_point("stt")
graph.add_edge("stt", "llm")
graph.add_edge("llm", "tts")
graph.add_edge("tts", END)

voice_agent = graph.compile()

# %%
record_audio(seconds=5)

# %%
result = voice_agent.invoke({})
result["audio"]
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
