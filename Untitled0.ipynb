# %% [markdown]
# <a href="https://colab.research.google.com/github/AnanyaMadanala/ChatBot-Usng-Python/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google import genai
import os
api_key='AIzaSyA7RY7YHTX8TXYsU1GJe_RoGV99lV5flo8'
client=genai.Client(api_key=api_key)
print("-- genAI tester--type exit to quit")
while True:
  user_prompt=input("\nUser:")
  if user_prompt.lower() in ['exit', 'quit']:
    break
  try:
    response=client.models.generate_content(
        model="gemini-2.5-flash",
        contents=user_prompt
    )
    print(f"Ai:{response.text}")
  except Exception as e:
    print(f"Error:{e}")
# Out:
# -- genAI tester--type exit to quit
#
# User:exit
